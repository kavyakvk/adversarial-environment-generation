# %% [markdown]
# Visualizes fitness over time
# Fitness := number of food collected / number of agents

# %%
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

with open('GA_RandomAgent_100_iterations_2', 'rb') as f:
    raw_values = pickle.load(f)
raw_fitness_values = raw_values['fitness values']
grids = raw_values['grids']
env_params = raw_values['env_params']

avg_fitness_values = [-1*sum(i)/len(i) for i in raw_fitness_values]

# %%
sns.set(style='darkgrid')
ax = sns.scatterplot(data=avg_fitness_values)
plt.title('RandomAgent Fitness over 100 GA iterations')
# Set x-axis label
plt.xlabel('Iteration')
# Set y-axis label
plt.ylabel('Food collected per agent')

print(env_params)
# Out:
# {'coding_dict': {'empty': 0, 'agent': 1, 'bounds': 2, 'hive': 3, 'blockade': 4, 'food_start': 5}, 'N': 10, 'M': 10, 'max_food': 5, 'observation_radius': 1, 'steps': 300, 'spawn_rate': 2, 'pheromone': {'evaporation': 0.05, 'diffusion': 0.1, 'step': 0.1, 'step_if_food': 0.3, 'cap': 5}, 'grid': {'food': 40, 'blockade': 20}, 'rgb_coding': {0: [0, 0, 0], 1: [150, 0, 150], 2: [100, 100, 100], 3: [150, 150, 0], 4: [45, 0, 255], 5: [0, 255, 45], 6: (0, 250, 50), 7: (0, 245, 55), 8: (0, 240, 60), 9: (0, 235, 65), 10: (0, 230, 70), 11: (0, 225, 75), 12: (0, 220, 80), 13: (0, 215, 85), 14: (0, 210, 90)}}
